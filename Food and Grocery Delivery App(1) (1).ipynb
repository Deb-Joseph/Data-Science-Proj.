# %%
#import libraries
import numpy as np
import pandas as pd
pd.set_option("display.precision", 2)

# %%
df = pd.read_csv('Food and Grocery Delivery App.csv')
df.head(200)
# Out:
#                        Timestamp     Age? Marital Status?  Gender  \
# 0    2023/04/02 9:12:18 PM GMT+1  15 - 25          Single  Female
# 1    2023/04/02 9:12:56 PM GMT+1  26 - 35          Single  Female
# 2    2023/04/02 9:21:53 PM GMT+1  15 - 25          Single    Male
# 3    2023/04/02 9:25:47 PM GMT+1  26 - 35          Single  Female
# 4    2023/04/02 9:26:39 PM GMT+1  26 - 35          Single    Male
# ..                           ...      ...             ...     ...
# 125  2023/04/03 6:31:08 PM GMT+1  15 - 25          Single    Male
# 126  2023/04/03 6:46:38 PM GMT+1  15 - 25         Married    Male
# 127  2023/04/03 6:52:11 PM GMT+1  26 - 35          Single    Male
# 128  2023/04/03 7:00:39 PM GMT+1  26 - 35          Single  Female
# 129  2023/04/03 7:21:58 PM GMT+1  26 - 35          Single    Male
#
#           Location?  \
# 0    Lagos Mainland
# 1    Lagos Mainland
# 2             Other
# 3             Other
# 4             Other
# ..              ...
# 125           Other
# ...

# %%
print(df.columns)
# Out:
# Index(['Timestamp', 'Age?', 'Marital Status?', 'Gender', 'Location?',
#        'Which is the most popular dish you would buy from a restaurant or online vendor?',
#        'If local, what are the dishes you would love to buy?',
#        'If Intercontinental, what are the dishes you would love to buy?',
#        'Have you ever shopped for your food or groceries online?',
#        'Would you trust a grocery shopper to help you shop for your groceries and food or do it yourself?',
#        'What quality would you expect in a grocery shopper?',
#        'What products/foodstuffs would you love your grocery shopper to help youwith? [Food products]',
#        'Which food and groceries delivery app are you most familiar with?',
#        'Why do you use this food app?',
#        'Which restaurant or vendors do you frequently order from when you use the food app you selected?',
#        'What factors are most important to you when selecting a restaurant or vendor on a food app [Factors]',
# ...

# %%
## What are the most popular cuisines and dishes among users of the food app?

# %%
df['Which is the most popular dish you would buy from a restaurant or online vendor?'].value_counts()
# Out:
# Local dishes               104
# Intercontinental dishes     26
# Name: Which is the most popular dish you would buy from a restaurant or online vendor?, dtype: int64

# %%
df['If local, what are the dishes you would love to buy?'].value_counts()
# Out:
# Amala                   4
# Jollof rice             3
# Swallow                 3
# Rice                    3
# Rice                    3
#                        ..
# Amala and Gbegiri       1
# Yes                     1
# Amala                   1
# Amala & ewedu           1
# Pounded yam and soup    1
# Name: If local, what are the dishes you would love to buy?, Length: 115, dtype: int64

# %%
df['If Intercontinental, what are the dishes you would love to buy?'].value_counts()
# Out:
# Nil                                                                                   2
# Chinese food                                                                          2
# Fried rice                                                                            2
# Chinese Rice                                                                          2
# Fried rice with chicken                                                               1
# Mexican rice                                                                          1
# Chinese rice                                                                          1
# French fries                                                                          1
# Chinese fried rice and also korean kimchi and rice also a spicy bowl of 🍜 ramen       1
# Chinese and seafood                                                                   1
# Chinese meals                                                                         1
# ...

# %%
# How does the popularity of different cuisines and dishes vary by geographic region?

# %%
df['Location?'].value_counts()
# Out:
# Lagos Mainland    76
# Ibadan            24
# Other             21
# Lagos Island       9
# Name: Location?, dtype: int64

# %%
# What factors are most important to users when selecting a restaurant or dish on the food app 
# (e.g. price, proximity, reviews, cuisine)?

# %%
df['What factors are most important to you when selecting a restaurant or vendor on a food app [Factors]'].value_counts()
# Out:
# Price;Delivery time                                      22
# Price;Proximity                                          16
# Proximity                                                 8
# Price;Proximity;Delivery time                             8
# Price;Cuisine                                             8
# Price                                                     7
# Price;Reviews                                             6
# Reviews                                                   5
# Price;Proximity;Cuisine;Delivery time                     5
# Price;Proximity;Reviews;Delivery time                     4
# Proximity;Cuisine                                         4
# Price;Proximity;Reviews;Cuisine;Ratings;Delivery time     4
# Proximity;Delivery time                                   3
# Reviews;Delivery time                                     3
# Price;Proximity;Ratings;Delivery time                     3
# Price;Proximity;Reviews;Ratings;Delivery time             2
# ...

# %%
# Are there any seasonal trends in the popularity of certain dishes or cuisines on the food app?

# %%
df['Do you always have cravings for a particular dish during a particular season of the year?'].value_counts()
# Out:
# Yes    91
# No     39
# Name: Do you always have cravings for a particular dish during a particular season of the year?, dtype: int64

# %%
# Are there any notable differences in user behavior and preferences between the app's free and paid users?

# %%
df['Would you use the food and grocery app more if you had to subscribe?'].value_counts()
# Out:
# No       76
# Yes      50
# Maybe     4
# Name: Would you use the food and grocery app more if you had to subscribe?, dtype: int64

# %%
# How do promotions and discounts impact user behavior on the food app?

# %%
df['If there are more promotions and discounts, would you shop and order more?'].value_counts()
# Out:
# Yes    123
# No       7
# Name: If there are more promotions and discounts, would you shop and order more?, dtype: int64
